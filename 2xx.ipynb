# %%
import glob,cv2;
import warnings
warnings.filterwarnings('ignore')
import numpy as np;
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
data_hr=sorted(glob.glob('/media/DiskE/vdsr2x4x/pytorch-vdsr-l1loss/Set5_hr/*.*',recursive=True))
data_bic=sorted(glob.glob('/media/DiskE/vdsr2x4x/pytorch-vdsr-l1loss/Set5_bicubic_4x/*.*',recursive=True))
vdsr_l1_loss=sorted(glob.glob('/media/DiskE/vdsr2x4x/pytorch-vdsr-l1loss/result+2x/*.*',recursive=True))
vdsr_l2_loss=sorted(glob.glob('/media/DiskE/vdsr2x4x/pytorch-vdsr-l2loss/result+2x/*.*',recursive=True))
vdsr_l1_ov_l2_loss=sorted(glob.glob('/media/DiskE/vdsr2x4x/custom loss/l1over l2/result+2x/*.*',recursive=True))
vdsr_l2_ov_l1_loss=sorted(glob.glob('/media/DiskE/vdsr2x4x/custom loss/l2overl1/result+2x/*.*',recursive=True))
vdsr_vgg16_loss=sorted(glob.glob('/media/DiskE/result/Untitled Folder/vdsr_vgg16/x2/data/Set5/*.*',recursive=True))
vdsr_vgg19_loss=sorted(glob.glob('/media/DiskE/result/Untitled Folder/vdsr_vgg19/2x/Set5/x2/*.*',recursive=True))
rdn_l1_loss=sorted(glob.glob('/media/DiskE/vdsr2x4x/RDNSRnet/RDNSR 2x model and results/set5 result/*.*',recursive=True))
rdn_vgg16_loss=sorted(glob.glob('/media/DiskE/result/Untitled Folder/rdn_vgg16/Set5/x2/*.*',recursive=True))
rdn_vgg19_loss=sorted(glob.glob('/media/DiskE/result/Untitled Folder/rdn_vgg19/Set5_LR_x2/*.*',recursive=True))

# %%
w=np.random.randint(0,150);
h=np.random.randint(0,150);
fig = plt.figure(figsize=(20,20))
i=np.random.randint(0,5);
print(i)
print(w,h)
img1=data_hr[i]
img2=data_bic[i]
img3=vdsr_l1_loss[i]
img4=vdsr_l2_loss[i]
img5=vdsr_l1_ov_l2_loss[i]
img6=vdsr_l2_ov_l1_loss[i]
img7=vdsr_vgg16_loss[i]
img8=vdsr_vgg19_loss[i]
img9=rdn_l1_loss[i]
img10=rdn_vgg16_loss[i]
img11=rdn_vgg19_loss[i]

img=cv2.imread(img1,cv2.IMREAD_COLOR)
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

img1=cv2.imread(img1,cv2.IMREAD_COLOR)
img1=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

img2=cv2.imread(img2,cv2.IMREAD_COLOR)
img2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

img3=cv2.imread(img3,cv2.IMREAD_COLOR)
img3=cv2.cvtColor(img3,cv2.COLOR_BGR2RGB)

img4=cv2.imread(img4,cv2.IMREAD_COLOR)
img4=cv2.cvtColor(img4,cv2.COLOR_BGR2RGB)

img5=cv2.imread(img5,cv2.IMREAD_COLOR)
img5=cv2.cvtColor(img5,cv2.COLOR_BGR2RGB)

img6=cv2.imread(img6,cv2.IMREAD_COLOR)
img6=cv2.cvtColor(img6,cv2.COLOR_BGR2RGB)

img7=cv2.imread(img7,cv2.IMREAD_COLOR)
img7=cv2.cvtColor(img7,cv2.COLOR_BGR2RGB)

img8=cv2.imread(img8,cv2.IMREAD_COLOR)
img8=cv2.cvtColor(img8,cv2.COLOR_BGR2RGB)

img9=cv2.imread(img9,cv2.IMREAD_COLOR)
img9=cv2.cvtColor(img9,cv2.COLOR_BGR2RGB)

img10=cv2.imread(img10,cv2.IMREAD_COLOR)
img10=cv2.cvtColor(img10,cv2.COLOR_BGR2RGB)

img11=cv2.imread(img11,cv2.IMREAD_COLOR)
img11=cv2.cvtColor(img11,cv2.COLOR_BGR2RGB)


j=100
img1=img1[w:w+j,h:h+j]
img2=img2[w:w+j,h:h+j]
img3=img3[w:w+j,h:h+j]
img4=img4[w:w+j,h:h+j]
img5=img5[w:w+j,h:h+j]
img6=img6[w:w+j,h:h+j]
img7=img7[w:w+j,h:h+j]
img8=img8[w:w+j,h:h+j]
img9=img9[w:w+j,h:h+j]
img10=img10[w:w+j,h:h+j]
img11=img11[w:w+j,h:h+j]

cv2.rectangle(img, (w, h), (w+j, h+j), (255,0,0), 2)

ax=plt.subplot(3,4,1)
#plt.axis('off')
ax.imshow(img)
ax.set_title("Original")
ax.set_xlabel('PSNR').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,2)
#plt.axis('off')
ax.imshow(img1)
ax.set_title("Original")
ax.set_xlabel('PSNR').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,3)
ax.imshow(img2)
ax.set_title("Bicubic")
ax.set_xlabel('28.414').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,4)
ax.imshow(img3)
ax.set_title("vdsr_L1_loss")
ax.set_xlabel('31.356').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,5)
ax.imshow(img4)
ax.set_title("vdsr_L2_loss")
ax.set_xlabel('31.37').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,6)
ax.imshow(img5)
ax.set_title("vdsr_L1_ov_L2")
ax.set_xlabel('31.401').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,7)
ax.imshow(img6)
ax.set_title("vdsr_L2_ov_L1")
ax.set_xlabel('31.368').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,8)
ax.imshow(img7)
ax.set_title("vdsr_vgg16")
ax.set_xlabel('29.24').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,9)
ax.imshow(img8)
ax.set_title("vdsr_vgg19")
ax.set_xlabel('29.22').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,10)
ax.imshow(img9)
ax.set_title("rdn_l1_loss")
ax.set_xlabel('32.61').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,11)
ax.imshow(img10)
ax.set_title("rdn_vgg16")
ax.set_xlabel('30.42').set_color('red')
plt.xticks([])
plt.yticks([])

ax=plt.subplot(3,4,12)
ax.imshow(img11)
ax.set_title("rdn_vgg19")
ax.set_xlabel('30.92').set_color('red')
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 1
# 94 118
